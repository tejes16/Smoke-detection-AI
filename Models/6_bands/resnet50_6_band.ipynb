# %%
# !pip install rasterio
# !pip install Pillow
# !pip install -U tensorflow
# !pip install -U keras
# !pip install git+https://github.com/qubvel/segmentation_models
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 61.0 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2023.5.7)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.3)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.22.4)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.0)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.8 snuggs-1.4.7
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (8.4.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.56.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.10)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Collecting keras
#   Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 36.8 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires keras<2.13,>=2.12.0, but you have keras 2.13.1 which is incompatible.
# Successfully installed keras-2.13.1
# Collecting git+https://github.com/qubvel/segmentation_models
#   Cloning https://github.com/qubvel/segmentation_models to /tmp/pip-req-build-x31a0iyi
#   Running command git clone --filter=blob:none --quiet https://github.com/qubvel/segmentation_models /tmp/pip-req-build-x31a0iyi
#   Resolved https://github.com/qubvel/segmentation_models to commit e951c6747f75fa9e7240816d1c79dd2e66813123
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Collecting keras_applications<=1.0.8,>=1.0.7 (from segmentation-models==1.0.1)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 5.8 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models==1.0.1)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models==1.0.1)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation-models==1.0.1) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_applications<=1.0.8,>=1.0.7->segmentation-models==1.0.1) (1.22.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_applications<=1.0.8,>=1.0.7->segmentation-models==1.0.1) (3.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (23.1)
# Building wheels for collected packages: segmentation-models
#   Building wheel for segmentation-models (setup.py) ... done
#   Created wheel for segmentation-models: filename=segmentation_models-1.0.1-py3-none-any.whl size=33791 sha256=40322d2630e0b3d78059b7687cc520e32dc66702cb857642b6cfea06de6e26c2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ea46kqz7/wheels/ce/d6/f1/5d00e82b3893c5f1ffee43bf7b8877148af09c7c9c6c4882c9
# Successfully built segmentation-models
# Installing collected packages: keras_applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras_applications-1.0.8 segmentation-models-1.0.1

# %%
# !pip install tensorflow==2.12.0
# Out:
# Requirement already satisfied: tensorflow==2.12.0 in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.56.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.4.10)
# Collecting keras<2.13,>=2.12.0 (from tensorflow==2.12.0)
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 45.9 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.2.2)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
# Successfully installed keras-2.12.0

# %%
# !pip install -U -q segmentation-models
# !pip install -q tensorflow==2.2.1
# !pip install -q keras==2.5
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

from tensorflow import keras
import segmentation_models as sm
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.2.1 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2)
# ERROR: No matching distribution found for tensorflow==2.2.1
# ERROR: Could not find a version that satisfies the requirement keras==2.5 (from versions: 0.2.0, 0.3.0, 0.3.1, 0.3.2, 0.3.3, 1.0.0, 1.0.1, 1.0.2, 1.0.3, 1.0.4, 1.0.5, 1.0.6, 1.0.7, 1.0.8, 1.1.0, 1.1.1, 1.1.2, 1.2.0, 1.2.1, 1.2.2, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.0.4, 2.0.5, 2.0.6, 2.0.7, 2.0.8, 2.0.9, 2.1.0, 2.1.1, 2.1.2, 2.1.3, 2.1.4, 2.1.5, 2.1.6, 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.2.4, 2.2.5, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.4.2, 2.4.3, 2.5.0rc0, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0rc3, 2.6.0, 2.7.0rc0, 2.7.0rc2, 2.7.0, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.10.0rc0, 2.10.0rc1, 2.10.0, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0rc3, 2.11.0, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.13.1rc0, 2.13.1rc1, 2.13.1)
# ERROR: No matching distribution found for keras==2.5
# Segmentation Models: using `tf.keras` framework.

# %%
import tensorflow as tf
import cv2
import matplotlib
import os,re
import rasterio
from random import randint
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from rasterio.plot import show, show_hist
from sklearn.model_selection import train_test_split
import sys,traceback,signal
import keras
import segmentation_models as sm

# %%
import cv2
import os
import rasterio
import numpy as np
from sklearn.model_selection import train_test_split
import segmentation_models as sm

dataset_path = "/content/drive/MyDrive/Tiles"
image_folder = os.path.join(dataset_path, "Rasters")
mask_folder = os.path.join(dataset_path, "Masks")

image_files = sorted(os.listdir(image_folder))
mask_files = sorted(os.listdir(mask_folder))

# Check if the number of images and masks match
if len(image_files) != len(mask_files):
    raise ValueError("Number of images and masks don't match")

num_images = len(image_files)

# Lists to store the loaded images and masks
images = []
masks = []

for i in range(num_images):
    image_path = os.path.join(image_folder, image_files[i])
    mask_path = os.path.join(mask_folder, mask_files[i])

    # Open the image and mask using rasterio
    with rasterio.open(image_path) as src:
        image = src.read()  # Read all the channels

    with rasterio.open(mask_path) as src:
        mask = src.read(1)  # Read only the first channel (assuming the mask is single-channel)

    # Append the image and mask to the respective lists
    images.append(image)
    masks.append(mask)

# Convert the lists to numpy arrays
images = np.array(images)
masks = np.array(masks)

# Print the shape of the loaded dataset
print("Images shape:", images.shape)
print("Masks shape:", masks.shape)

##########################################################

intxtrain, intxtest, intytrain, intytest = train_test_split(images, masks, test_size=0.2, random_state=5)

##########################################################

BACKBONE = "resnet50"
preprocess = sm.get_preprocessing(BACKBONE)

############################################################

model = sm.Unet(backbone_name=BACKBONE, encoder_weights=None, input_shape=(256, 256, 6))
model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
model.summary()

############################################################

intxtrain = np.transpose(intxtrain, (0, 2, 3, 1))
intxtest = np.transpose(intxtest, (0, 2, 3, 1))
intytrain = (intytrain / 255).astype(np.float32)
intytest = (intytest / 255).astype(np.float32)

intxval = intxtest[:(len(intxtest) // 2)]
intxtest = intxtest[(len(intxtest) // 2):len(intxtest)]
intyval = intytest[:(len(intytest) // 2)]
intytest = intytest[(len(intytest) // 2):len(intytest)]

#############################################################

history = model.fit(x=intxtrain, y=intytrain, batch_size=64, verbose=1, epochs=20, validation_data=(intxval, intyval))
# Out:
# Images shape: (1050, 6, 256, 256)
# Masks shape: (1050, 256, 256)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 256, 256, 6  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 256, 256, 6)  18          ['data[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 262, 262, 6)  0          ['bn_data[0][0]']
#
#  conv0 (Conv2D)                 (None, 128, 128, 64  18816       ['zero_padding2d[0][0]']
#                                 )
#
#  bn0 (BatchNormalization)       (None, 128, 128, 64  256         ['conv0[0][0]']
#                                 )
#
#  relu0 (Activation)             (None, 128, 128, 64  0           ['bn0[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 130, 130, 64  0          ['relu0[0][0]']
#  D)                             )
#
#  pooling0 (MaxPooling2D)        (None, 64, 64, 64)   0           ['zero_padding2d_1[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 64, 64, 64)  256         ['pooling0[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 64, 64, 64)  0           ['stage1_unit1_bn1[0][0]']
#  )
#
#  stage1_unit1_conv1 (Conv2D)    (None, 64, 64, 64)   4096        ['stage1_unit1_relu1[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 64, 64, 64)  0           ['stage1_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 66, 66, 64)  0           ['stage1_unit1_relu2[0][0]']
#  D)
#
#  stage1_unit1_conv2 (Conv2D)    (None, 64, 64, 64)   36864       ['zero_padding2d_2[0][0]']
#
#  stage1_unit1_bn3 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit1_conv2[0][0]']
#  zation)
#
#  stage1_unit1_relu3 (Activation  (None, 64, 64, 64)  0           ['stage1_unit1_bn3[0][0]']
#  )
#
#  stage1_unit1_conv3 (Conv2D)    (None, 64, 64, 256)  16384       ['stage1_unit1_relu3[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 64, 64, 256)  16384       ['stage1_unit1_relu1[0][0]']
#
#  add (Add)                      (None, 64, 64, 256)  0           ['stage1_unit1_conv3[0][0]',
#                                                                   'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 64, 64, 256)  1024       ['add[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 64, 64, 256)  0          ['stage1_unit2_bn1[0][0]']
#  )
#
#  stage1_unit2_conv1 (Conv2D)    (None, 64, 64, 64)   16384       ['stage1_unit2_relu1[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 64, 64, 64)  0           ['stage1_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 66, 66, 64)  0           ['stage1_unit2_relu2[0][0]']
#  D)
#
#  stage1_unit2_conv2 (Conv2D)    (None, 64, 64, 64)   36864       ['zero_padding2d_3[0][0]']
#
#  stage1_unit2_bn3 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit2_conv2[0][0]']
#  zation)
#
#  stage1_unit2_relu3 (Activation  (None, 64, 64, 64)  0           ['stage1_unit2_bn3[0][0]']
#  )
#
#  stage1_unit2_conv3 (Conv2D)    (None, 64, 64, 256)  16384       ['stage1_unit2_relu3[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 256)  0           ['stage1_unit2_conv3[0][0]',
#                                                                   'add[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, 64, 64, 256)  1024       ['add_1[0][0]']
#  zation)
#
#  stage1_unit3_relu1 (Activation  (None, 64, 64, 256)  0          ['stage1_unit3_bn1[0][0]']
#  )
#
#  stage1_unit3_conv1 (Conv2D)    (None, 64, 64, 64)   16384       ['stage1_unit3_relu1[0][0]']
#
#  stage1_unit3_bn2 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit3_conv1[0][0]']
#  zation)
#
#  stage1_unit3_relu2 (Activation  (None, 64, 64, 64)  0           ['stage1_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_4 (ZeroPadding2  (None, 66, 66, 64)  0           ['stage1_unit3_relu2[0][0]']
#  D)
#
#  stage1_unit3_conv2 (Conv2D)    (None, 64, 64, 64)   36864       ['zero_padding2d_4[0][0]']
#
#  stage1_unit3_bn3 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit3_conv2[0][0]']
#  zation)
#
#  stage1_unit3_relu3 (Activation  (None, 64, 64, 64)  0           ['stage1_unit3_bn3[0][0]']
#  )
#
#  stage1_unit3_conv3 (Conv2D)    (None, 64, 64, 256)  16384       ['stage1_unit3_relu3[0][0]']
#
#  add_2 (Add)                    (None, 64, 64, 256)  0           ['stage1_unit3_conv3[0][0]',
#                                                                   'add_1[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, 64, 64, 256)  1024       ['add_2[0][0]']
#  zation)
#
#  stage2_unit1_relu1 (Activation  (None, 64, 64, 256)  0          ['stage2_unit1_bn1[0][0]']
#  )
#
#  stage2_unit1_conv1 (Conv2D)    (None, 64, 64, 128)  32768       ['stage2_unit1_relu1[0][0]']
#
#  stage2_unit1_bn2 (BatchNormali  (None, 64, 64, 128)  512        ['stage2_unit1_conv1[0][0]']
#  zation)
#
#  stage2_unit1_relu2 (Activation  (None, 64, 64, 128)  0          ['stage2_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_5 (ZeroPadding2  (None, 66, 66, 128)  0          ['stage2_unit1_relu2[0][0]']
#  D)
#
#  stage2_unit1_conv2 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_5[0][0]']
#
#  stage2_unit1_bn3 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit1_conv2[0][0]']
#  zation)
#
#  stage2_unit1_relu3 (Activation  (None, 32, 32, 128)  0          ['stage2_unit1_bn3[0][0]']
#  )
#
#  stage2_unit1_conv3 (Conv2D)    (None, 32, 32, 512)  65536       ['stage2_unit1_relu3[0][0]']
#
#  stage2_unit1_sc (Conv2D)       (None, 32, 32, 512)  131072      ['stage2_unit1_relu1[0][0]']
#
#  add_3 (Add)                    (None, 32, 32, 512)  0           ['stage2_unit1_conv3[0][0]',
#                                                                   'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, 32, 32, 512)  2048       ['add_3[0][0]']
#  zation)
#
#  stage2_unit2_relu1 (Activation  (None, 32, 32, 512)  0          ['stage2_unit2_bn1[0][0]']
#  )
#
#  stage2_unit2_conv1 (Conv2D)    (None, 32, 32, 128)  65536       ['stage2_unit2_relu1[0][0]']
#
#  stage2_unit2_bn2 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit2_conv1[0][0]']
#  zation)
#
#  stage2_unit2_relu2 (Activation  (None, 32, 32, 128)  0          ['stage2_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_6 (ZeroPadding2  (None, 34, 34, 128)  0          ['stage2_unit2_relu2[0][0]']
#  D)
#
#  stage2_unit2_conv2 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_6[0][0]']
#
#  stage2_unit2_bn3 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit2_conv2[0][0]']
#  zation)
#
#  stage2_unit2_relu3 (Activation  (None, 32, 32, 128)  0          ['stage2_unit2_bn3[0][0]']
#  )
#
#  stage2_unit2_conv3 (Conv2D)    (None, 32, 32, 512)  65536       ['stage2_unit2_relu3[0][0]']
#
#  add_4 (Add)                    (None, 32, 32, 512)  0           ['stage2_unit2_conv3[0][0]',
#                                                                   'add_3[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, 32, 32, 512)  2048       ['add_4[0][0]']
#  zation)
#
#  stage2_unit3_relu1 (Activation  (None, 32, 32, 512)  0          ['stage2_unit3_bn1[0][0]']
#  )
#
#  stage2_unit3_conv1 (Conv2D)    (None, 32, 32, 128)  65536       ['stage2_unit3_relu1[0][0]']
#
#  stage2_unit3_bn2 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit3_conv1[0][0]']
#  zation)
#
#  stage2_unit3_relu2 (Activation  (None, 32, 32, 128)  0          ['stage2_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_7 (ZeroPadding2  (None, 34, 34, 128)  0          ['stage2_unit3_relu2[0][0]']
#  D)
#
#  stage2_unit3_conv2 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_7[0][0]']
#
#  stage2_unit3_bn3 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit3_conv2[0][0]']
#  zation)
#
#  stage2_unit3_relu3 (Activation  (None, 32, 32, 128)  0          ['stage2_unit3_bn3[0][0]']
#  )
#
#  stage2_unit3_conv3 (Conv2D)    (None, 32, 32, 512)  65536       ['stage2_unit3_relu3[0][0]']
#
#  add_5 (Add)                    (None, 32, 32, 512)  0           ['stage2_unit3_conv3[0][0]',
#                                                                   'add_4[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, 32, 32, 512)  2048       ['add_5[0][0]']
#  zation)
#
#  stage2_unit4_relu1 (Activation  (None, 32, 32, 512)  0          ['stage2_unit4_bn1[0][0]']
#  )
#
#  stage2_unit4_conv1 (Conv2D)    (None, 32, 32, 128)  65536       ['stage2_unit4_relu1[0][0]']
#
#  stage2_unit4_bn2 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit4_conv1[0][0]']
#  zation)
#
#  stage2_unit4_relu2 (Activation  (None, 32, 32, 128)  0          ['stage2_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_8 (ZeroPadding2  (None, 34, 34, 128)  0          ['stage2_unit4_relu2[0][0]']
#  D)
#
#  stage2_unit4_conv2 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_8[0][0]']
#
#  stage2_unit4_bn3 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit4_conv2[0][0]']
#  zation)
#
#  stage2_unit4_relu3 (Activation  (None, 32, 32, 128)  0          ['stage2_unit4_bn3[0][0]']
#  )
#
#  stage2_unit4_conv3 (Conv2D)    (None, 32, 32, 512)  65536       ['stage2_unit4_relu3[0][0]']
#
#  add_6 (Add)                    (None, 32, 32, 512)  0           ['stage2_unit4_conv3[0][0]',
#                                                                   'add_5[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, 32, 32, 512)  2048       ['add_6[0][0]']
#  zation)
#
#  stage3_unit1_relu1 (Activation  (None, 32, 32, 512)  0          ['stage3_unit1_bn1[0][0]']
#  )
#
#  stage3_unit1_conv1 (Conv2D)    (None, 32, 32, 256)  131072      ['stage3_unit1_relu1[0][0]']
#
#  stage3_unit1_bn2 (BatchNormali  (None, 32, 32, 256)  1024       ['stage3_unit1_conv1[0][0]']
#  zation)
#
#  stage3_unit1_relu2 (Activation  (None, 32, 32, 256)  0          ['stage3_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_9 (ZeroPadding2  (None, 34, 34, 256)  0          ['stage3_unit1_relu2[0][0]']
#  D)
#
#  stage3_unit1_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_9[0][0]']
#
#  stage3_unit1_bn3 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit1_conv2[0][0]']
#  zation)
#
#  stage3_unit1_relu3 (Activation  (None, 16, 16, 256)  0          ['stage3_unit1_bn3[0][0]']
#  )
#
#  stage3_unit1_conv3 (Conv2D)    (None, 16, 16, 1024  262144      ['stage3_unit1_relu3[0][0]']
#                                 )
#
#  stage3_unit1_sc (Conv2D)       (None, 16, 16, 1024  524288      ['stage3_unit1_relu1[0][0]']
#                                 )
#
#  add_7 (Add)                    (None, 16, 16, 1024  0           ['stage3_unit1_conv3[0][0]',
#                                 )                                 'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, 16, 16, 1024  4096       ['add_7[0][0]']
#  zation)                        )
#
#  stage3_unit2_relu1 (Activation  (None, 16, 16, 1024  0          ['stage3_unit2_bn1[0][0]']
#  )                              )
#
#  stage3_unit2_conv1 (Conv2D)    (None, 16, 16, 256)  262144      ['stage3_unit2_relu1[0][0]']
#
#  stage3_unit2_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit2_conv1[0][0]']
#  zation)
#
#  stage3_unit2_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_10 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit2_relu2[0][0]']
#  2D)
#
#  stage3_unit2_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_10[0][0]']
#
#  stage3_unit2_bn3 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit2_conv2[0][0]']
#  zation)
#
#  stage3_unit2_relu3 (Activation  (None, 16, 16, 256)  0          ['stage3_unit2_bn3[0][0]']
#  )
#
#  stage3_unit2_conv3 (Conv2D)    (None, 16, 16, 1024  262144      ['stage3_unit2_relu3[0][0]']
#                                 )
#
#  add_8 (Add)                    (None, 16, 16, 1024  0           ['stage3_unit2_conv3[0][0]',
#                                 )                                 'add_7[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, 16, 16, 1024  4096       ['add_8[0][0]']
#  zation)                        )
#
#  stage3_unit3_relu1 (Activation  (None, 16, 16, 1024  0          ['stage3_unit3_bn1[0][0]']
#  )                              )
#
#  stage3_unit3_conv1 (Conv2D)    (None, 16, 16, 256)  262144      ['stage3_unit3_relu1[0][0]']
#
#  stage3_unit3_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit3_conv1[0][0]']
#  zation)
#
#  stage3_unit3_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_11 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit3_relu2[0][0]']
#  2D)
#
#  stage3_unit3_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_11[0][0]']
#
#  stage3_unit3_bn3 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit3_conv2[0][0]']
#  zation)
#
#  stage3_unit3_relu3 (Activation  (None, 16, 16, 256)  0          ['stage3_unit3_bn3[0][0]']
#  )
#
#  stage3_unit3_conv3 (Conv2D)    (None, 16, 16, 1024  262144      ['stage3_unit3_relu3[0][0]']
#                                 )
#
#  add_9 (Add)                    (None, 16, 16, 1024  0           ['stage3_unit3_conv3[0][0]',
#                                 )                                 'add_8[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, 16, 16, 1024  4096       ['add_9[0][0]']
#  zation)                        )
#
#  stage3_unit4_relu1 (Activation  (None, 16, 16, 1024  0          ['stage3_unit4_bn1[0][0]']
#  )                              )
#
#  stage3_unit4_conv1 (Conv2D)    (None, 16, 16, 256)  262144      ['stage3_unit4_relu1[0][0]']
#
#  stage3_unit4_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit4_conv1[0][0]']
#  zation)
#
#  stage3_unit4_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_12 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit4_relu2[0][0]']
#  2D)
#
#  stage3_unit4_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_12[0][0]']
#
#  stage3_unit4_bn3 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit4_conv2[0][0]']
#  zation)
#
#  stage3_unit4_relu3 (Activation  (None, 16, 16, 256)  0          ['stage3_unit4_bn3[0][0]']
#  )
#
#  stage3_unit4_conv3 (Conv2D)    (None, 16, 16, 1024  262144      ['stage3_unit4_relu3[0][0]']
#                                 )
#
#  add_10 (Add)                   (None, 16, 16, 1024  0           ['stage3_unit4_conv3[0][0]',
#                                 )                                 'add_9[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, 16, 16, 1024  4096       ['add_10[0][0]']
#  zation)                        )
#
#  stage3_unit5_relu1 (Activation  (None, 16, 16, 1024  0          ['stage3_unit5_bn1[0][0]']
#  )                              )
#
#  stage3_unit5_conv1 (Conv2D)    (None, 16, 16, 256)  262144      ['stage3_unit5_relu1[0][0]']
#
#  stage3_unit5_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit5_conv1[0][0]']
#  zation)
#
#  stage3_unit5_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit5_bn2[0][0]']
#  )
#
#  zero_padding2d_13 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit5_relu2[0][0]']
#  2D)
#
#  stage3_unit5_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_13[0][0]']
#
#  stage3_unit5_bn3 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit5_conv2[0][0]']
#  zation)
#
#  stage3_unit5_relu3 (Activation  (None, 16, 16, 256)  0          ['stage3_unit5_bn3[0][0]']
#  )
#
#  stage3_unit5_conv3 (Conv2D)    (None, 16, 16, 1024  262144      ['stage3_unit5_relu3[0][0]']
#                                 )
#
#  add_11 (Add)                   (None, 16, 16, 1024  0           ['stage3_unit5_conv3[0][0]',
#                                 )                                 'add_10[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, 16, 16, 1024  4096       ['add_11[0][0]']
#  zation)                        )
#
#  stage3_unit6_relu1 (Activation  (None, 16, 16, 1024  0          ['stage3_unit6_bn1[0][0]']
#  )                              )
#
#  stage3_unit6_conv1 (Conv2D)    (None, 16, 16, 256)  262144      ['stage3_unit6_relu1[0][0]']
#
#  stage3_unit6_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit6_conv1[0][0]']
#  zation)
#
#  stage3_unit6_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit6_bn2[0][0]']
#  )
#
#  zero_padding2d_14 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit6_relu2[0][0]']
#  2D)
#
#  stage3_unit6_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_14[0][0]']
#
#  stage3_unit6_bn3 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit6_conv2[0][0]']
#  zation)
#
#  stage3_unit6_relu3 (Activation  (None, 16, 16, 256)  0          ['stage3_unit6_bn3[0][0]']
#  )
#
#  stage3_unit6_conv3 (Conv2D)    (None, 16, 16, 1024  262144      ['stage3_unit6_relu3[0][0]']
#                                 )
#
#  add_12 (Add)                   (None, 16, 16, 1024  0           ['stage3_unit6_conv3[0][0]',
#                                 )                                 'add_11[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, 16, 16, 1024  4096       ['add_12[0][0]']
#  zation)                        )
#
#  stage4_unit1_relu1 (Activation  (None, 16, 16, 1024  0          ['stage4_unit1_bn1[0][0]']
#  )                              )
#
#  stage4_unit1_conv1 (Conv2D)    (None, 16, 16, 512)  524288      ['stage4_unit1_relu1[0][0]']
#
#  stage4_unit1_bn2 (BatchNormali  (None, 16, 16, 512)  2048       ['stage4_unit1_conv1[0][0]']
#  zation)
#
#  stage4_unit1_relu2 (Activation  (None, 16, 16, 512)  0          ['stage4_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_15 (ZeroPadding  (None, 18, 18, 512)  0          ['stage4_unit1_relu2[0][0]']
#  2D)
#
#  stage4_unit1_conv2 (Conv2D)    (None, 8, 8, 512)    2359296     ['zero_padding2d_15[0][0]']
#
#  stage4_unit1_bn3 (BatchNormali  (None, 8, 8, 512)   2048        ['stage4_unit1_conv2[0][0]']
#  zation)
#
#  stage4_unit1_relu3 (Activation  (None, 8, 8, 512)   0           ['stage4_unit1_bn3[0][0]']
#  )
#
#  stage4_unit1_conv3 (Conv2D)    (None, 8, 8, 2048)   1048576     ['stage4_unit1_relu3[0][0]']
#
#  stage4_unit1_sc (Conv2D)       (None, 8, 8, 2048)   2097152     ['stage4_unit1_relu1[0][0]']
#
#  add_13 (Add)                   (None, 8, 8, 2048)   0           ['stage4_unit1_conv3[0][0]',
#                                                                   'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, 8, 8, 2048)  8192        ['add_13[0][0]']
#  zation)
#
#  stage4_unit2_relu1 (Activation  (None, 8, 8, 2048)  0           ['stage4_unit2_bn1[0][0]']
#  )
#
#  stage4_unit2_conv1 (Conv2D)    (None, 8, 8, 512)    1048576     ['stage4_unit2_relu1[0][0]']
#
#  stage4_unit2_bn2 (BatchNormali  (None, 8, 8, 512)   2048        ['stage4_unit2_conv1[0][0]']
#  zation)
#
#  stage4_unit2_relu2 (Activation  (None, 8, 8, 512)   0           ['stage4_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_16 (ZeroPadding  (None, 10, 10, 512)  0          ['stage4_unit2_relu2[0][0]']
#  2D)
#
#  stage4_unit2_conv2 (Conv2D)    (None, 8, 8, 512)    2359296     ['zero_padding2d_16[0][0]']
#
#  stage4_unit2_bn3 (BatchNormali  (None, 8, 8, 512)   2048        ['stage4_unit2_conv2[0][0]']
#  zation)
#
#  stage4_unit2_relu3 (Activation  (None, 8, 8, 512)   0           ['stage4_unit2_bn3[0][0]']
#  )
#
# ...
#
#  stage4_unit3_conv3 (Conv2D)    (None, 8, 8, 2048)   1048576     ['stage4_unit3_relu3[0][0]']
#
#  add_15 (Add)                   (None, 8, 8, 2048)   0           ['stage4_unit3_conv3[0][0]',
#                                                                   'add_14[0][0]']
#
#  bn1 (BatchNormalization)       (None, 8, 8, 2048)   8192        ['add_15[0][0]']
#
#  relu1 (Activation)             (None, 8, 8, 2048)   0           ['bn1[0][0]']
#
#  decoder_stage0_upsampling (UpS  (None, 16, 16, 2048  0          ['relu1[0][0]']
#  ampling2D)                     )
#
#  decoder_stage0_concat (Concate  (None, 16, 16, 3072  0          ['decoder_stage0_upsampling[0][0]
#  nate)                          )                                ',
#                                                                   'stage4_unit1_relu1[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, 16, 16, 256)  7077888     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 16, 16, 256)  1024       ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 16, 16, 256)  0          ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 16, 16, 256)  589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 16, 16, 256)  1024       ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 16, 16, 256)  0          ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 32, 32, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 32, 32, 768)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'stage3_unit1_relu1[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, 32, 32, 128)  884736      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 32, 32, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 32, 32, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 32, 32, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 32, 32, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 32, 32, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 64, 64, 128)  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage2_concat (Concate  (None, 64, 64, 384)  0          ['decoder_stage2_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'stage2_unit1_relu1[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, 64, 64, 64)   221184      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 64, 64, 64)  256         ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 64, 64, 64)  0           ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 64, 64, 64)   36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 64, 64, 64)  256         ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 64, 64, 64)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 128, 128, 64  0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage3_concat (Concate  (None, 128, 128, 12  0          ['decoder_stage3_upsampling[0][0]
#  nate)                          8)                               ',
#                                                                   'relu0[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, 128, 128, 32  36864       ['decoder_stage3_concat[0][0]']
#                                 )
#
#  decoder_stage3a_bn (BatchNorma  (None, 128, 128, 32  128        ['decoder_stage3a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage3a_relu (Activati  (None, 128, 128, 32  0          ['decoder_stage3a_bn[0][0]']
#  on)                            )
#
#  decoder_stage3b_conv (Conv2D)  (None, 128, 128, 32  9216        ['decoder_stage3a_relu[0][0]']
#                                 )
#
#  decoder_stage3b_bn (BatchNorma  (None, 128, 128, 32  128        ['decoder_stage3b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage3b_relu (Activati  (None, 128, 128, 32  0          ['decoder_stage3b_bn[0][0]']
#  on)                            )
#
#  decoder_stage4_upsampling (UpS  (None, 256, 256, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 256, 256, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 256, 256, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 256, 256, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 256, 256, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 256, 256, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 256, 256, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 256, 256, 1)  145         ['decoder_stage4b_relu[0][0]']
#
#  sigmoid (Activation)           (None, 256, 256, 1)  0           ['final_conv[0][0]']
#
# ==================================================================================================
# Total params: 32,570,531
# Trainable params: 32,522,967
# Non-trainable params: 47,564
# __________________________________________________________________________________________________
# Epoch 1/20
# 14/14 [==============================] - 109s 3s/step - loss: 1.3632 - iou_score: 0.1579 - val_loss: 3.4151 - val_iou_score: 1.7932e-05
# Epoch 2/20
# 14/14 [==============================] - 21s 1s/step - loss: 1.2338 - iou_score: 0.1776 - val_loss: 3.4150 - val_iou_score: 1.8663e-11
# Epoch 3/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.1939 - iou_score: 0.2031 - val_loss: 3.4150 - val_iou_score: 1.8663e-11
# Epoch 4/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.1807 - iou_score: 0.2105 - val_loss: 3.4152 - val_iou_score: 7.4646e-06
# Epoch 5/20
# 14/14 [==============================] - 19s 1s/step - loss: 1.1552 - iou_score: 0.2158 - val_loss: 3.4132 - val_iou_score: 8.5056e-05
# Epoch 6/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.1596 - iou_score: 0.2227 - val_loss: 3.4150 - val_iou_score: 0.0012
# Epoch 7/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.1396 - iou_score: 0.2339 - val_loss: 3.4110 - val_iou_score: 2.4180e-04
# Epoch 8/20
# 14/14 [==============================] - 19s 1s/step - loss: 1.1584 - iou_score: 0.2267 - val_loss: 3.3909 - val_iou_score: 0.0010
# Epoch 9/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.1359 - iou_score: 0.2299 - val_loss: 3.4631 - val_iou_score: 0.0034
# Epoch 10/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.1345 - iou_score: 0.2517 - val_loss: 3.2203 - val_iou_score: 0.0173
# Epoch 11/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.1209 - iou_score: 0.2591 - val_loss: 2.6098 - val_iou_score: 0.0923
# Epoch 12/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.1128 - iou_score: 0.2606 - val_loss: 3.9469 - val_iou_score: 0.1976
# Epoch 13/20
# 14/14 [==============================] - 19s 1s/step - loss: 1.1172 - iou_score: 0.2490 - val_loss: 7.4052 - val_iou_score: 0.1626
# Epoch 14/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.0944 - iou_score: 0.2634 - val_loss: 2.7992 - val_iou_score: 0.0788
# Epoch 15/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.0687 - iou_score: 0.2894 - val_loss: 2.2596 - val_iou_score: 0.2480
# Epoch 16/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.0755 - iou_score: 0.2870 - val_loss: 2.3150 - val_iou_score: 0.2194
# Epoch 17/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.0957 - iou_score: 0.2780 - val_loss: 1.6655 - val_iou_score: 0.1910
# Epoch 18/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.1133 - iou_score: 0.2672 - val_loss: 2.2134 - val_iou_score: 0.2039
# Epoch 19/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.1650 - iou_score: 0.2356 - val_loss: 1.4907 - val_iou_score: 0.1670
# Epoch 20/20
# 14/14 [==============================] - 20s 1s/step - loss: 1.1222 - iou_score: 0.2378 - val_loss: 1.9869 - val_iou_score: 0.2061

# %%
# Evaluate the model on the test set
score = model.evaluate(intxtest, intytest, verbose=0)
print("Test IoU Score:", score[1])

# Get the training history
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_iou = history.history['iou_score']
val_iou = history.history['val_iou_score']
epochs = range(1, len(train_loss) + 1)

# Plot the training and validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot the training and validation IoU
plt.subplot(1, 2, 2)
plt.plot(epochs, train_iou, 'b-', label='Training IoU')
plt.plot(epochs, val_iou, 'r-', label='Validation IoU')
plt.title('Training and Validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU Score')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# Test IoU Score: 0.23374652862548828

# %%
model.save("smoke_resent50_20epochs.h5")

# %%
from keras.models import load_model
import tensorflow.keras.backend as K
from tensorflow.keras.utils import CustomObjectScope
import segmentation_models as sm

# Define the custom loss function
def binary_crossentropy_plus_jaccard_loss(y_true, y_pred):
    bce_loss = K.binary_crossentropy(y_true, y_pred)
    jaccard_loss = sm.losses.jaccard_loss(y_true, y_pred)
    return bce_loss + jaccard_loss

# Define the custom metric function
def iou_score(y_true, y_pred):
    iou = sm.metrics.iou_score(y_true, y_pred)
    return iou

# Register the custom loss and metric functions
with CustomObjectScope({'binary_crossentropy_plus_jaccard_loss': binary_crossentropy_plus_jaccard_loss,
                        'iou_score': iou_score}):
    model = load_model('/content/sample_data/smoke_resent50_20epochs.h5')

# Compile the model with the desired optimizer, loss function, and metrics
model.compile(optimizer='adam',
              loss=binary_crossentropy_plus_jaccard_loss,
              metrics=[iou_score])


# Train the model for additional epochs
history = model.fit(x=intxtrain, y=intytrain, batch_size=32, verbose=1, epochs=20, validation_data=(intxval, intyval))

# Save the updated model
model.save('smoke_resnet50_40epoch.h5')
# Out:
# Epoch 1/20
# 27/27 [==============================] - 54s 704ms/step - loss: 1.2192 - iou_score: 0.1878 - val_loss: 1.4072 - val_iou_score: 0.1948
# Epoch 2/20
# 27/27 [==============================] - 18s 666ms/step - loss: 1.1471 - iou_score: 0.2381 - val_loss: 2.0167 - val_iou_score: 0.2166
# Epoch 3/20
# 27/27 [==============================] - 18s 674ms/step - loss: 1.1491 - iou_score: 0.2429 - val_loss: 1.8779 - val_iou_score: 0.2498
# Epoch 4/20
# 27/27 [==============================] - 18s 682ms/step - loss: 1.1306 - iou_score: 0.2465 - val_loss: 1.5682 - val_iou_score: 0.2774
# Epoch 5/20
# 27/27 [==============================] - 19s 715ms/step - loss: 1.1096 - iou_score: 0.2696 - val_loss: 1.5174 - val_iou_score: 0.3225
# Epoch 6/20
# 27/27 [==============================] - 20s 729ms/step - loss: 1.0925 - iou_score: 0.2800 - val_loss: 1.6411 - val_iou_score: 0.2638
# Epoch 7/20
# 27/27 [==============================] - 20s 725ms/step - loss: 1.1299 - iou_score: 0.2496 - val_loss: 1.4938 - val_iou_score: 0.3351
# Epoch 8/20
# 27/27 [==============================] - 19s 709ms/step - loss: 1.0881 - iou_score: 0.2815 - val_loss: 1.2321 - val_iou_score: 0.3234
# Epoch 9/20
# 27/27 [==============================] - 19s 711ms/step - loss: 1.0771 - iou_score: 0.2833 - val_loss: 1.1060 - val_iou_score: 0.3340
# Epoch 10/20
# 27/27 [==============================] - 19s 719ms/step - loss: 1.1281 - iou_score: 0.2550 - val_loss: 1.1183 - val_iou_score: 0.3113
# Epoch 11/20
# 27/27 [==============================] - 20s 753ms/step - loss: 1.0874 - iou_score: 0.2697 - val_loss: 1.0657 - val_iou_score: 0.3554
# Epoch 12/20
# 27/27 [==============================] - 20s 733ms/step - loss: 1.0748 - iou_score: 0.2903 - val_loss: 1.1321 - val_iou_score: 0.3138
# Epoch 13/20
# 27/27 [==============================] - 20s 736ms/step - loss: 1.0748 - iou_score: 0.2819 - val_loss: 1.2455 - val_iou_score: 0.2633
# Epoch 14/20
# 27/27 [==============================] - 21s 761ms/step - loss: 1.0575 - iou_score: 0.3004 - val_loss: 1.1766 - val_iou_score: 0.3196
# Epoch 15/20
# 27/27 [==============================] - 20s 760ms/step - loss: 1.1216 - iou_score: 0.2635 - val_loss: 1.2045 - val_iou_score: 0.2837
# Epoch 16/20
# 27/27 [==============================] - 20s 739ms/step - loss: 1.0942 - iou_score: 0.2793 - val_loss: 1.1253 - val_iou_score: 0.3156
# Epoch 17/20
# 27/27 [==============================] - 20s 760ms/step - loss: 1.0540 - iou_score: 0.2973 - val_loss: 1.0812 - val_iou_score: 0.3328
# Epoch 18/20
# 27/27 [==============================] - 20s 760ms/step - loss: 1.0588 - iou_score: 0.3115 - val_loss: 1.2177 - val_iou_score: 0.2929
# Epoch 19/20
# 27/27 [==============================] - 20s 756ms/step - loss: 1.0710 - iou_score: 0.2949 - val_loss: 1.2242 - val_iou_score: 0.3119
# Epoch 20/20
# 27/27 [==============================] - 20s 760ms/step - loss: 1.0348 - iou_score: 0.3028 - val_loss: 1.1217 - val_iou_score: 0.3359

# %%
# Evaluate the model on the test set
score = model.evaluate(intxtest, intytest, verbose=0)
print("Test IoU Score:", score[1])

# Get the training history
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_iou = history.history['iou_score']
val_iou = history.history['val_iou_score']
epochs = range(1, len(train_loss) + 1)

# Plot the training and validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot the training and validation IoU
plt.subplot(1, 2, 2)
plt.plot(epochs, train_iou, 'b-', label='Training IoU')
plt.plot(epochs, val_iou, 'r-', label='Validation IoU')
plt.title('Training and Validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU Score')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# Test IoU Score: 0.3936435282230377

# %%
from google.colab import files

# Specify the path of the file you want to download
file_path = "/content/smoke_resnet50_40epoch"

# Download the file
files.download(file_path)

# %%
from keras.models import load_model
import tensorflow.keras.backend as K
from tensorflow.keras.utils import CustomObjectScope
import segmentation_models as sm

# Define the custom loss function
def binary_crossentropy_plus_jaccard_loss(y_true, y_pred):
    bce_loss = K.binary_crossentropy(y_true, y_pred)
    jaccard_loss = sm.losses.jaccard_loss(y_true, y_pred)
    return bce_loss + jaccard_loss

# Define the custom metric function
def iou_score(y_true, y_pred):
    iou = sm.metrics.iou_score(y_true, y_pred)
    return iou

# Register the custom loss and metric functions
with CustomObjectScope({'binary_crossentropy_plus_jaccard_loss': binary_crossentropy_plus_jaccard_loss,
                        'iou_score': iou_score}):
    model = load_model('/content/smoke_resnet50_40epoch.h5')

# Compile the model with the desired optimizer, loss function, and metrics
model.compile(optimizer='adam',
              loss=binary_crossentropy_plus_jaccard_loss,
              metrics=[iou_score])


# Train the model for additional epochs
history = model.fit(x=intxtrain, y=intytrain, batch_size=32, verbose=1, epochs=60, validation_data=(intxval, intyval))

# Save the updated model
model.save('smoke_resnet50_100epoch.h5')
# Out:
# Epoch 1/60
# 27/27 [==============================] - 55s 788ms/step - loss: 1.0463 - iou_score: 0.3082 - val_loss: 1.0442 - val_iou_score: 0.3126
# Epoch 2/60
# 27/27 [==============================] - 20s 758ms/step - loss: 1.0527 - iou_score: 0.2938 - val_loss: 1.2591 - val_iou_score: 0.3244
# Epoch 3/60
# 27/27 [==============================] - 20s 756ms/step - loss: 1.0413 - iou_score: 0.3111 - val_loss: 1.1015 - val_iou_score: 0.3269
# Epoch 4/60
# 27/27 [==============================] - 19s 721ms/step - loss: 1.0681 - iou_score: 0.2955 - val_loss: 1.2796 - val_iou_score: 0.3134
# Epoch 5/60
# 27/27 [==============================] - 20s 757ms/step - loss: 1.0274 - iou_score: 0.3074 - val_loss: 1.0715 - val_iou_score: 0.3174
# Epoch 6/60
# 27/27 [==============================] - 20s 743ms/step - loss: 1.0411 - iou_score: 0.3024 - val_loss: 1.1826 - val_iou_score: 0.2876
# Epoch 7/60
# 27/27 [==============================] - 20s 739ms/step - loss: 1.0239 - iou_score: 0.3211 - val_loss: 1.1696 - val_iou_score: 0.2260
# Epoch 8/60
# 27/27 [==============================] - 20s 756ms/step - loss: 1.0224 - iou_score: 0.3218 - val_loss: 1.0380 - val_iou_score: 0.3517
# Epoch 9/60
# 27/27 [==============================] - 20s 757ms/step - loss: 1.0408 - iou_score: 0.3152 - val_loss: 1.1147 - val_iou_score: 0.3370
# Epoch 10/60
# 27/27 [==============================] - 20s 760ms/step - loss: 1.0246 - iou_score: 0.3246 - val_loss: 1.0818 - val_iou_score: 0.3018
# Epoch 11/60
# 27/27 [==============================] - 20s 760ms/step - loss: 1.0138 - iou_score: 0.3248 - val_loss: 1.0570 - val_iou_score: 0.3512
# Epoch 12/60
# 27/27 [==============================] - 21s 762ms/step - loss: 1.0216 - iou_score: 0.3323 - val_loss: 1.0758 - val_iou_score: 0.3177
# Epoch 13/60
# 27/27 [==============================] - 20s 760ms/step - loss: 1.0262 - iou_score: 0.3220 - val_loss: 1.1283 - val_iou_score: 0.3275
# Epoch 14/60
# 27/27 [==============================] - 20s 760ms/step - loss: 1.0255 - iou_score: 0.3119 - val_loss: 1.0557 - val_iou_score: 0.3340
# Epoch 15/60
# 27/27 [==============================] - 20s 760ms/step - loss: 1.0162 - iou_score: 0.3217 - val_loss: 1.1937 - val_iou_score: 0.2318
# Epoch 16/60
# 27/27 [==============================] - 20s 757ms/step - loss: 1.0052 - iou_score: 0.3331 - val_loss: 1.0888 - val_iou_score: 0.2993
# Epoch 17/60
# 27/27 [==============================] - 20s 758ms/step - loss: 1.0234 - iou_score: 0.3196 - val_loss: 1.0611 - val_iou_score: 0.3091
# Epoch 18/60
# 27/27 [==============================] - 20s 737ms/step - loss: 1.0259 - iou_score: 0.3182 - val_loss: 1.1611 - val_iou_score: 0.3155
# Epoch 19/60
# 27/27 [==============================] - 20s 760ms/step - loss: 0.9775 - iou_score: 0.3414 - val_loss: 1.0516 - val_iou_score: 0.3350
# Epoch 20/60
# 27/27 [==============================] - 20s 734ms/step - loss: 0.9948 - iou_score: 0.3346 - val_loss: 1.0586 - val_iou_score: 0.3029
# Epoch 21/60
# 27/27 [==============================] - 20s 757ms/step - loss: 0.9946 - iou_score: 0.3322 - val_loss: 1.1263 - val_iou_score: 0.3193
# Epoch 22/60
# 27/27 [==============================] - 20s 755ms/step - loss: 0.9863 - iou_score: 0.3446 - val_loss: 1.1603 - val_iou_score: 0.3140
# Epoch 23/60
# 27/27 [==============================] - 20s 732ms/step - loss: 0.9546 - iou_score: 0.3649 - val_loss: 1.0763 - val_iou_score: 0.3487
# Epoch 24/60
# 27/27 [==============================] - 20s 733ms/step - loss: 0.9778 - iou_score: 0.3529 - val_loss: 1.1023 - val_iou_score: 0.2935
# Epoch 25/60
# 27/27 [==============================] - 20s 756ms/step - loss: 0.9751 - iou_score: 0.3512 - val_loss: 1.0536 - val_iou_score: 0.3139
# Epoch 26/60
# 27/27 [==============================] - 20s 735ms/step - loss: 0.9469 - iou_score: 0.3708 - val_loss: 1.0695 - val_iou_score: 0.3056
# Epoch 27/60
# 27/27 [==============================] - 20s 757ms/step - loss: 0.9830 - iou_score: 0.3513 - val_loss: 1.3616 - val_iou_score: 0.3074
# Epoch 28/60
# 27/27 [==============================] - 20s 756ms/step - loss: 0.9646 - iou_score: 0.3593 - val_loss: 1.0819 - val_iou_score: 0.3329
# Epoch 29/60
# 27/27 [==============================] - 20s 758ms/step - loss: 0.9647 - iou_score: 0.3526 - val_loss: 1.0697 - val_iou_score: 0.3304
# Epoch 30/60
# 27/27 [==============================] - 20s 735ms/step - loss: 0.9474 - iou_score: 0.3661 - val_loss: 1.0934 - val_iou_score: 0.3246
# Epoch 31/60
# 27/27 [==============================] - 20s 736ms/step - loss: 0.9543 - iou_score: 0.3591 - val_loss: 1.1125 - val_iou_score: 0.2895
# Epoch 32/60
# 27/27 [==============================] - 20s 736ms/step - loss: 0.9664 - iou_score: 0.3572 - val_loss: 1.1195 - val_iou_score: 0.3245
# Epoch 33/60
# 27/27 [==============================] - 20s 737ms/step - loss: 0.9566 - iou_score: 0.3603 - val_loss: 1.0878 - val_iou_score: 0.3090
# Epoch 34/60
# 27/27 [==============================] - 20s 760ms/step - loss: 0.9988 - iou_score: 0.3415 - val_loss: 1.0203 - val_iou_score: 0.3389
# Epoch 35/60
# 27/27 [==============================] - 20s 760ms/step - loss: 0.9783 - iou_score: 0.3493 - val_loss: 1.0672 - val_iou_score: 0.3229
# Epoch 36/60
# 27/27 [==============================] - 20s 736ms/step - loss: 0.9452 - iou_score: 0.3693 - val_loss: 1.0612 - val_iou_score: 0.3349
# Epoch 37/60
# 27/27 [==============================] - 20s 737ms/step - loss: 0.9509 - iou_score: 0.3669 - val_loss: 1.2060 - val_iou_score: 0.3088
# Epoch 38/60
# 27/27 [==============================] - 20s 738ms/step - loss: 0.9531 - iou_score: 0.3657 - val_loss: 1.4016 - val_iou_score: 0.2990
# Epoch 39/60
# 27/27 [==============================] - 20s 760ms/step - loss: 0.9825 - iou_score: 0.3528 - val_loss: 1.1718 - val_iou_score: 0.3185
# Epoch 40/60
# 27/27 [==============================] - 20s 738ms/step - loss: 0.9501 - iou_score: 0.3593 - val_loss: 1.0845 - val_iou_score: 0.3351
# Epoch 41/60
# 27/27 [==============================] - 20s 738ms/step - loss: 0.9178 - iou_score: 0.3891 - val_loss: 1.0874 - val_iou_score: 0.3198
# Epoch 42/60
# 27/27 [==============================] - 20s 760ms/step - loss: 0.9760 - iou_score: 0.3638 - val_loss: 1.1609 - val_iou_score: 0.3071
# Epoch 43/60
# 27/27 [==============================] - 20s 739ms/step - loss: 0.9707 - iou_score: 0.3555 - val_loss: 1.1501 - val_iou_score: 0.3380
# Epoch 44/60
# 27/27 [==============================] - 20s 760ms/step - loss: 0.9418 - iou_score: 0.3710 - val_loss: 1.1298 - val_iou_score: 0.3279
# Epoch 45/60
# 27/27 [==============================] - 20s 738ms/step - loss: 0.9257 - iou_score: 0.3884 - val_loss: 1.4710 - val_iou_score: 0.3129
# Epoch 46/60
# 27/27 [==============================] - 21s 761ms/step - loss: 0.9045 - iou_score: 0.4044 - val_loss: 1.0372 - val_iou_score: 0.3321
# Epoch 47/60
# 27/27 [==============================] - 21s 762ms/step - loss: 0.8684 - iou_score: 0.4212 - val_loss: 1.1095 - val_iou_score: 0.3456
# Epoch 48/60
# 27/27 [==============================] - 20s 736ms/step - loss: 0.9057 - iou_score: 0.3975 - val_loss: 1.0706 - val_iou_score: 0.3250
# Epoch 49/60
# 27/27 [==============================] - 20s 738ms/step - loss: 0.8902 - iou_score: 0.4109 - val_loss: 1.0858 - val_iou_score: 0.3304
# Epoch 50/60
# 27/27 [==============================] - 20s 738ms/step - loss: 0.8929 - iou_score: 0.4129 - val_loss: 1.0829 - val_iou_score: 0.3228
# Epoch 51/60
# 27/27 [==============================] - 20s 737ms/step - loss: 0.9055 - iou_score: 0.3989 - val_loss: 1.0922 - val_iou_score: 0.3044
# Epoch 52/60
# 27/27 [==============================] - 20s 739ms/step - loss: 0.8823 - iou_score: 0.4149 - val_loss: 1.1137 - val_iou_score: 0.3004
# Epoch 53/60
# 27/27 [==============================] - 20s 737ms/step - loss: 0.8923 - iou_score: 0.4046 - val_loss: 1.1073 - val_iou_score: 0.3275
# Epoch 54/60
# 27/27 [==============================] - 21s 761ms/step - loss: 0.8898 - iou_score: 0.3979 - val_loss: 1.1248 - val_iou_score: 0.3188
# Epoch 55/60
# 27/27 [==============================] - 20s 737ms/step - loss: 0.8914 - iou_score: 0.4099 - val_loss: 1.1097 - val_iou_score: 0.3500
# Epoch 56/60
# 27/27 [==============================] - 20s 760ms/step - loss: 0.9120 - iou_score: 0.3915 - val_loss: 1.4391 - val_iou_score: 0.3019
# Epoch 57/60
# 27/27 [==============================] - 20s 761ms/step - loss: 0.9437 - iou_score: 0.3799 - val_loss: 1.2934 - val_iou_score: 0.3191
# Epoch 58/60
# 27/27 [==============================] - 20s 737ms/step - loss: 0.8705 - iou_score: 0.4160 - val_loss: 1.2710 - val_iou_score: 0.3265
# Epoch 59/60
# 27/27 [==============================] - 20s 761ms/step - loss: 0.8564 - iou_score: 0.4299 - val_loss: 1.0666 - val_iou_score: 0.3420
# Epoch 60/60
# 27/27 [==============================] - 20s 736ms/step - loss: 0.8603 - iou_score: 0.4270 - val_loss: 1.0883 - val_iou_score: 0.3058

# %%
# Evaluate the model on the test set
score = model.evaluate(intxtest, intytest, verbose=0)
print("Test IoU Score:", score[1])

# Get the training history
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_iou = history.history['iou_score']
val_iou = history.history['val_iou_score']
epochs = range(1, len(train_loss) + 1)

# Plot the training and validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot the training and validation IoU
plt.subplot(1, 2, 2)
plt.plot(epochs, train_iou, 'b-', label='Training IoU')
plt.plot(epochs, val_iou, 'r-', label='Validation IoU')
plt.title('Training and Validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU Score')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# Test IoU Score: 0.3141854703426361

# %%
from keras.models import load_model
import tensorflow.keras.backend as K
from tensorflow.keras.utils import CustomObjectScope
import segmentation_models as sm

# Define the custom loss function
def binary_crossentropy_plus_jaccard_loss(y_true, y_pred):
    bce_loss = K.binary_crossentropy(y_true, y_pred)
    jaccard_loss = sm.losses.jaccard_loss(y_true, y_pred)
    return bce_loss + jaccard_loss

# Define the custom metric function
def iou_score(y_true, y_pred):
    iou = sm.metrics.iou_score(y_true, y_pred)
    return iou

# Register the custom loss and metric functions
with CustomObjectScope({'binary_crossentropy_plus_jaccard_loss': binary_crossentropy_plus_jaccard_loss,
                        'iou_score': iou_score}):
    model = load_model('/content/sample_data/smoke_resent50_20epochs.h5')

# Compile the model with the desired optimizer, loss function, and metrics
model.compile(optimizer='adam',
              loss=binary_crossentropy_plus_jaccard_loss,
              metrics=[iou_score])


# Train the model for additional epochs
history = model.fit(x=intxtrain, y=intytrain, batch_size=32, verbose=1, epochs=60, validation_data=(intxval, intyval))

# Save the updated model
model.save('smoke_resnet50_100epoch.h5')
